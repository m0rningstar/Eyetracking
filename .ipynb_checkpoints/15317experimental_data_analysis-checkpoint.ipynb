# %% [markdown]
# ## Обработка айтрекинговых данных

# %% [markdown]
# ### # эксперимент 15/03/17

# %% [markdown]
# В качестве основного инструмента будем использовать модуль pandas, потому что это более-менее быстро и удобно. Файл event_processor.py импортируем ради нескольких полезных функций. Для визуализации будем использовать Bokeh.

# %%
import os
from event_processor import *
import pandas as pd
from bokeh.plotting import figure
from bokeh.io import push_notebook, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e957a3a8-8908-48f7-b932-2d55d15370ee">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# В raw_events загружаем путь к текстовому файлу с событиями, который получается на выходе SMI IDF Event Detector. В raw_markers -- путь к маркерам эскперимента.

# %%
raw_events=os.path.abspath('3-15-17 Events.txt')
raw_markers=os.path.abspath('tracking_markers.csv')

# %% [markdown]
# В events_dictionary записываем словарь, который будет содержать датафреймы для всех типов событий, доступные по ключам.

# %%
events_dictionary=process_events(raw_events, debug=False)
events_dictionary.keys()
# Out:
# ['Saccade L',
#  'Fixation L',
#  'User Event',
#  'Blink R',
#  'Blink L',
#  'Fixation R',
#  'Saccade R']

# %% [markdown]
# Дальше для обработки будем использовать данные по фиксациям с левого глаза (для правого все, естественно, будет аналогично).

# %%
fixations=events_dictionary['Fixation L']

# %%
fixations.drop(['Trial','Number', 'Dispersion X', 'Dispersion Y', 'Plane', 'Avg. Pupil Size X', 
                'Avg Pupil Size Y'], axis=1, inplace=True)
fixations[['Location X','Location Y']] = fixations[['Location X','Location Y']].apply(pd.to_numeric)
fixations.drop(fixations[(fixations['Location X']<=0) | (fixations['Location Y']<=0)].index, axis=0, inplace=True)

# %% [markdown]
# В markers записываем датафрейм с маркерами эксперимента.

# %%
markers=pd.read_csv(raw_markers, sep='\t', header=0, index_col=0, engine='python')

# %% [markdown]
# Выбираем из этого датафрейма записи с метками начала ("777") и конца ("888") трайлов.

# %%
markers[(markers['Marker']==777) | (markers['Marker']==888)]
# Out:
#             Start  Marker
# 0     11322251346   777.0
# 105   11346324402   888.0
# 106   11347336777   777.0
# 211   11371404228   888.0
# 212   11372418813   777.0
# 317   11396562539   888.0
# 318   11397587079   777.0
# 423   11421814134   888.0
# 424   11422837471   777.0
# 529   11447173565   888.0
# 530   11448191093   777.0
# 635   11472633275   888.0
# 636   11473660990   777.0
# 741   11498179459   888.0
# 742   11499193866   777.0
# 847   11523507125   888.0
# 848   11524528323   777.0
# 953   11549244099   888.0
# 954   11550261357   777.0
# 1059  11575070124   888.0
# 1060  11576083318   777.0
# 1165  11600965576   888.0
# 1166  11601983358   777.0
# 1271  11626971447   888.0
# 1272  11627985527   777.0
# 1377  11653055935   888.0

# %% [markdown]
# Теперь выбираем из датафрейма с фиксациями все записи, относящиеся к временному интервалу первого трайла:

# %%
s1_fix=find_fixations(fixations, time=(markers.loc[0, 'Start'], markers.loc[105, 'Start']))
s1_fix
# Out:
#     index         Start          End  Duration  Location X  Location Y
# 0       2  1.132249e+10  11322575419   89897.0      742.38      513.62
# 1       3  1.132302e+10  11323123662  103924.0      390.49      281.98
# 2       4  1.132332e+10  11323395975   74114.0      327.49      442.02
# 3       5  1.132376e+10  11323814090   50006.0      431.86      607.52
# 4       6  1.132590e+10  11325976889   72011.0      367.44      519.49
# 5       7  1.132638e+10  11326447091   67999.0      374.15      546.54
# 6       8  1.132696e+10  11327011329   54028.0      405.16      572.92
# 7       9  1.132904e+10  11329144174  106129.0      354.42      496.66
# 8      10  1.132930e+10  11329372287   70124.0      357.77      518.72
# 9      11  1.132965e+10  11329720401   67995.0      397.72      602.22
# 10     12  1.132989e+10  11329948510   61995.0      347.96      493.77
# 11     13  1.133101e+10  11331138929  126028.0      372.98      486.69
# 12     14  1.133212e+10  11332205368   85988.0      353.57      391.86
# 13     15  1.133280e+10  11332975710  178131.0      359.31      437.41
# 14     16  1.133332e+10  11333409928   94128.0      353.26      482.78
# 15     17  1.133517e+10  11335292649  126072.0      367.82      465.01
# 16     18  1.133533e+10  11335388653   57958.0      344.37      416.46
# 17     19  1.133559e+10  11335664796   70039.0      360.53      410.31
# 18     20  1.133572e+10  11335794870   70125.0      427.82      468.29
# 19     21  1.133609e+10  11336279001  184012.0      379.65      478.06
# 20     22  1.133644e+10  11336533109   89992.0      365.60      421.75
# 21     23  1.133684e+10  11336987347  144130.0      370.47      470.48
# 22     24  1.133900e+10  11339104205  104115.0      351.51      428.95
# 23     25  1.133921e+10  11339316321  102121.0      357.12      435.75
# 24     26  1.134008e+10  11340146655   64133.0      379.57      380.92
# 25     27  1.134035e+10  11340480760  134151.0      393.00      447.31
# 26     28  1.134125e+10  11341311097   60028.0      378.66      499.83
# 27     29  1.134134e+10  11341445218  106061.0      368.69      386.97
# 28     30  1.134162e+10  11341803335  182104.0      370.15      421.72
# 29     31  1.134605e+10  11346139091   93968.0      699.33      485.67
# 30     32  1.134632e+10  11346543218  224062.0      682.89      344.93

# %% [markdown]
# Теперь выберем все фиксации, которые относятся к участку, на котором находится тот символ, на котором должен был сконцентрировать внимание испытуемый.

# %% [markdown]
# Для начала разберемся с расположением символов на экране. В positions запишем координаты центров всех символов на экране (относительно центра самого экрана), в stimuli_size - размер символа (px), shrinkage - сжатие матрицы.

# %%
positions=[[-600, 375], [-400, 375], [-200, 375], [0, 375], [200, 375], [400, 375],
           [-600, 250], [-400, 250], [-200, 250], [0, 250], [200, 250], [400, 250],
           [-600, 125], [-400, 125], [-200, 125], [0, 125], [200, 125], [400, 125],
           [-600, 0], [-400, 0], [-200, 0], [0, 0], [200, 0], [400, 0], 
           [-600, -125],[-400, -125], [-200, -125], [0, -125], [200, -125], [400, -125], 
           [-600, -250],[-400, -250], [-200, -250], [0, -250], [200, -250], [400, -250], 
           [-600, -375],[-400, -375], [-200, -375], [0, -375], [200, -375], [400, -375]]
stimuli_size=100
shrinkage=1.32
resolution=(1680, 1050)

# %% [markdown]
# Пересчитаем координаты в границы всех символов на экране и запишем их в coors:

# %%
coors=matrix_coordinates(positions, resolution, stimuli_size,shrinkage)

# %% [markdown]
# В sequence будут храниться координаты последовательности символов, которые набирал испытуемый. *Science sucks :D*

# %%
sequence=[coors[18], coors[2], coors[8], coors[4], coors[13], coors[2], coors[4],
         coors[26],
         coors[18], coors[20], coors[2], coors[10], coors[18]]

# %% [markdown]
# Наконец, можно посмотреть на список всех фиксаций, относящихся к тому участку экрана, на котором находился первый символ:

# %%
s1_fix_r=find_fixations(s1_fix,time=(0,11653055935), area=sequence[0])
s1_fix_r
# Out:
#    level_0  index         Start          End  Duration  Location X  Location Y
# 0        4      6  1.132590e+10  11325976889   72011.0      367.44      519.49
# 1        5      7  1.132638e+10  11326447091   67999.0      374.15      546.54
# 2        6      8  1.132696e+10  11327011329   54028.0      405.16      572.92
# 3        7      9  1.132904e+10  11329144174  106129.0      354.42      496.66
# 4        8     10  1.132930e+10  11329372287   70124.0      357.77      518.72
# 5       10     12  1.132989e+10  11329948510   61995.0      347.96      493.77
# 6       11     13  1.133101e+10  11331138929  126028.0      372.98      486.69
# 7       14     16  1.133332e+10  11333409928   94128.0      353.26      482.78
# 8       19     21  1.133609e+10  11336279001  184012.0      379.65      478.06
# 9       26     28  1.134125e+10  11341311097   60028.0      378.66      499.83

# %% [markdown]
# Средняя длительность фиксации на этом участке (в микросекундах):

# %%
s1_fix_r['Duration'].mean()
# Out:
# 89648.2

# %% [markdown]
# Теперь отсортируем нерелевантные фиксации (во всех других местах экрана за пределами нужного участка):

# %%
sf= pd.merge(s1_fix, s1_fix_r, how='outer', indicator=True)
s1_fix_ur = sf[sf['_merge']=='left_only'][s1_fix.columns]
s1_fix_ur.reset_index(inplace=True)
s1_fix_ur
# Out:
#     level_0  index         Start          End  Duration  Location X  \
# 0         0      2  1.132249e+10  11322575419   89897.0      742.38
# 1         1      3  1.132302e+10  11323123662  103924.0      390.49
# 2         2      4  1.132332e+10  11323395975   74114.0      327.49
# 3         3      5  1.132376e+10  11323814090   50006.0      431.86
# 4         9     11  1.132965e+10  11329720401   67995.0      397.72
# 5        12     14  1.133212e+10  11332205368   85988.0      353.57
# 6        13     15  1.133280e+10  11332975710  178131.0      359.31
# 7        15     17  1.133517e+10  11335292649  126072.0      367.82
# 8        16     18  1.133533e+10  11335388653   57958.0      344.37
# 9        17     19  1.133559e+10  11335664796   70039.0      360.53
# 10       18     20  1.133572e+10  11335794870   70125.0      427.82
# 11       20     22  1.133644e+10  11336533109   89992.0      365.60
# 12       21     23  1.133684e+10  11336987347  144130.0      370.47
# 13       22     24  1.133900e+10  11339104205  104115.0      351.51
# 14       23     25  1.133921e+10  11339316321  102121.0      357.12
# 15       24     26  1.134008e+10  11340146655   64133.0      379.57
# 16       25     27  1.134035e+10  11340480760  134151.0      393.00
# 17       27     29  1.134134e+10  11341445218  106061.0      368.69
# 18       28     30  1.134162e+10  11341803335  182104.0      370.15
# 19       29     31  1.134605e+10  11346139091   93968.0      699.33
# 20       30     32  1.134632e+10  11346543218  224062.0      682.89
#
#     Location Y
# 0       513.62
# 1       281.98
# 2       442.02
# 3       607.52
# 4       602.22
# 5       391.86
# 6       437.41
# 7       465.01
# 8       416.46
# 9       410.31
# 10      468.29
# 11      421.75
# 12      470.48
# 13      428.95
# 14      435.75
# 15      380.92
# 16      447.31
# 17      386.97
# 18      421.72
# 19      485.67
# 20      344.93

# %% [markdown]
# Средняя длительность нерелевантной фиксации (в микросекундах):

# %%
s1_fix_ur['Duration'].mean()
# Out:
# 105670.76190476191

# %% [markdown]
# Т.е. нерелевантные фиксации были в cреднем длиннее релевантных.

# %% [markdown]
# Посмотрим на распределение фиксаций разной длительности по матрице:

# %%
plot = figure(title="Matrix overlay", y_range=(1050,0), x_range=(0, 1680),
              plot_width=840,
              plot_height=525,
              x_axis_label='width, pixels', 
              y_axis_label='height, pixels')

x1=s1_fix_r['Location X']
y1=s1_fix_r['Location Y']
radii1 = s1_fix_r['Duration']*0.0001

x2=s1_fix_ur['Location X']
y2=s1_fix_ur['Location Y']
radii2 = s1_fix_ur['Duration']*0.0001

for item in coors:
    if item == sequence[0]:
        #plot.quad(top=item[3], bottom=item[1], left=item[0], right=item[2], color="red", fill_alpha=0.3, line_color=None)
        plot.quad(top=item[1], bottom=item[3], left=item[0], right=item[2], color="red", fill_alpha=0.3, line_color=None)
    else:
        #plot.quad(top=item[3], bottom=item[1], left=item[0], right=item[2], color="blue", fill_alpha=0.3, line_color=None)
        plot.quad(top=item[1], bottom=item[3], left=item[0], right=item[2], color="blue", fill_alpha=0.3, line_color=None)
        
plot.circle(x2,y2, radius=radii2, fill_color="navy", fill_alpha=0.5, line_color=None, legend="irrelevant fixations")
plot.circle(x1,y1, radius=radii1, fill_color="firebrick", fill_alpha=0.6, line_color=None, legend="relevant fixations")

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f125251d-fd61-4ed8-a120-828354ac5e92"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f125251d-fd61-4ed8-a120-828354ac5e92").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f125251d-fd61-4ed8-a120-828354ac5e92");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f125251d-fd61-4ed8-a120-828354ac5e92' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5c70f922-c502-4730-80d9-a97175f5b08d":{"roots":{"references":[{"attributes":{"callback":null},"id":"388b930f-6e78-492a-bbf1-aa620a2ca395","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"a186723b-46bb-4582-a040-9e034e76a9dd","type":"BoxAnnotation"},"plot":{"id":"eb4154e0-e492-47c0-8339-37da109ca35c","subtype":"Figure","type":"Plot"}},"id":"c178668f-fb36-4c65-8bc0-97b8c2c96b19","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"83f0acb7-79ed-435a-9672-ebe3c6fbf84e","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":380.3030303030303},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"value":1093.030303030303},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":1193.030303030303},"top":{"value":480.3030303030303}},"id":"a7db9d17-0fb0-4087-bcf4-b9e4fa73aed0","type":"Quad"},{"attributes":{"bottom":{"value":190.90909090909093},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"value":941.5151515151515},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{
             x_axis_label='time since the start of experiment, microseconds', 
             y_axis_label='duration, microseconds')

x3=s1_fix_r['Start']
y3=s1_fix_r['Duration']

x4=s1_fix_ur['Start']
y4=s1_fix_ur['Duration']

for item in list(targets['Start']):
    plot2.quad(top=300000, bottom=0, left=item, right=item+50000, color="red", 
               fill_alpha=0.5, line_color=None, legend="relevant flashes")
    
plot2.circle(x3, y3, fill_color="firebrick", line_color=None, fill_alpha=0.6, size=10, legend="relevant fixations")
plot2.circle(x4, y4, fill_color="navy", line_color=None,fill_alpha=0.6, size=10, legend="irrelevant fixations")    

show(plot2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="552d7bad-cbc9-45f6-9853-20acf90be25f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("552d7bad-cbc9-45f6-9853-20acf90be25f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("552d7bad-cbc9-45f6-9853-20acf90be25f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '552d7bad-cbc9-45f6-9853-20acf90be25f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ca95838c-4cb9-4a49-9cae-5f6f11c2f6fe":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2bf70008-b47f-4d11-ab06-d522c565f15c","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"8cbb4b87-5aec-4cc9-94f5-8ae863955efd","type":"ColumnDataSource"},"glyph":{"id":"9d1f7113-2897-4af8-a1d3-e66bfebab089","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"cc35a19c-e383-4e14-aa84-e984bf36103f","type":"Quad"},"selection_glyph":null},"id":"9108fd8f-ad5f-4d4c-87f4-7d008ac04fe1","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"210392f7-282d-4def-a3ae-42b9719d64d8","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"left":{"value":11322851047},"line_color":{"value":null},"right":{"value":11322901047},"top":{"value":300000}},"id":"84015a02-c983-4c5e-a082-0e8464507416","type":"Quad"},{"attributes":{"data_source":{"id":"d04737eb-2f1b-4597-8a4f-a8756703a006","type":"ColumnDataSource"},"glyph":{"id":"f91bea87-96b8-4662-a9c7-61b746483235","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"06840096-67a0-4621-a4fc-c0fc3a1029c3","type":"Quad"},"selection_glyph":null},"id":"8f80b4b6-0ddc-49d7-87e0-a07968942497","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f1cd9d51-b1e3-4575-a966-2165438212a9","type":"ColumnDataSource"},"glyph":{"id":"329fd164-aca0-406a-8b87-4bf287b141df","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"64240934-5cfb-4bf7-a213-cfcc3de703dd","type":"Circle"},"selection_glyph":null},"id":"d2812058-143b-43b5-acee-0d5d159cfa26","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"left":{"value":11341263672},"line_color":{"value":null},"right":{"value":11341313672},"top":{"value":300000}},"id":"5f544caf-6cce-4a39-9b5a-f6e2be839397","type":"Quad"},{"attributes":{"callback":null},"id":"51de5340-de80-4f35-96ee-24b1f5d746df","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"left":{"value":11330459460},"line_color":{"value":null},"right":{"value":11330509460},"top":{"value":300000}},"id":"f1f8ee08-447f-44d3-beae-f5f100ff04be","type":"Quad"},{"attributes":{"data_source":{"id":"db31996c-aea9-4703-b1e5-9f617d648a24","type":"ColumnDataSource"},"glyph":{"id":"5ca4e6f4-760d-4212-8fe8-9d59a39d7271","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"7f623b4c-bfa4-45c0-9862-f7bf3dca4af7","type":"Quad"},"selection_glyph":null},"id":"ec0a9a60-6afe-4f80-974b-e5677cebb70e","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"76b08a6a-8798-42ba-bd7d-93ed953f4ede","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"value":11342664276},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":11342714276},"top":{"value":300000}},"id":"f19772f1-1c12-4980-a345-45a0cc98c47f","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"value":11336260020},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":11336310020},"top":{"value":300000}},"id":"cc35a19c-e383-4e14-aa84-e984bf36103f","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"left":{"value":11336860376},"line_color":{"value":null},"right":{"value":11336910376},"top":{"value":300000}},"id":"2428f281-31a6-42b1-a80b-d4dc763347ab","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"left":{"value":11324050721} ...

# %% [markdown]
# Можно также проделать все эти манипуляции для другого символа, например, второй буквы "E":

# %% [markdown]
# Релевантные фиксации:

# %%
c2_fix=find_fixations(fixations, time=(markers.loc[636, 'Start'], markers.loc[741, 'Start']))
c2_fix_r=find_fixations(fixations, area=sequence[6])
c2_fix_r
# Out:
#     index         Start          End  Duration  Location X  Location Y
# 0     136  1.139760e+10  11397675971   76245.0      941.63      264.73
# 1     149  1.140477e+10  11404826726   52126.0      961.99      272.63
# 2     168  1.141996e+10  11420174633  212059.0      954.77      271.05
# 3     296  1.147216e+10  11472229670   68006.0      984.12      251.09
# 4     298  1.147346e+10  11473900326  442085.0      953.39      270.00
# 5     301  1.147544e+10  11475679106  242090.0      946.97      225.00
# 6     302  1.147588e+10  11475933218   52001.0      947.11      220.30
# 7     305  1.147681e+10  11476911647  100097.0      951.89      283.26
# 8     312  1.147998e+10  11480170985  186143.0      945.50      247.87
# 9     318  1.148180e+10  11481939593  135993.0      992.29      220.90
# 10    319  1.148199e+10  11482209710  219986.0      959.36      195.19
# 11    320  1.148229e+10  11482419800  125973.0      943.73      250.26
# 12    321  1.148248e+10  11482569921   86119.0      957.79      204.89
# 13    326  1.148494e+10  11485341030  404234.0      946.13      276.25
# 14    327  1.148541e+10  11486199358  794326.0      973.64      213.52
# 15    330  1.148661e+10  11486667580   55969.0      988.22      276.31
# 16    331  1.148672e+10  11486909680  186099.0      951.39      268.58
# 17    332  1.148695e+10  11487085666  133975.0      984.02      202.28
# 18    333  1.148716e+10  11487435906  274136.0      944.58      249.91
# 19    335  1.148820e+10  11488368231  167994.0      951.32      193.91
# 20    337  1.148857e+10  11489192544  618205.0      966.60      216.16
# 21    339  1.148963e+10  11490128997  502230.0      964.65      194.27
# 22    348  1.149210e+10  11492191742   89997.0      973.57      219.12
# 23    350  1.149250e+10  11492808068  304083.0      949.06      244.69
# 24    353  1.149342e+10  11493542289  125988.0      957.60      217.49
# 25    354  1.149358e+10  11493816390  231972.0     1001.39      228.00
# 26    355  1.149391e+10  11494246621  338096.0      972.68      193.83
# 27    356  1.149428e+10  11494758853  476258.0      982.63      193.90
# 28    638  1.160527e+10  11605663765  398239.0      947.27      289.61
# 29    653  1.161331e+10  11613430852  124029.0      987.98      283.60

# %% [markdown]
# 31      184.21
# 32      226.14
# 33      243.57
# 34      208.17
# 35        0.38

# %% [markdown]
# Последнюю строчку из этого датафрейма убираем, т.к. там странная очень долгая фиксация в верхнем углу экрана.

# %%
c2_fix_ur.drop(c2_fix_ur.index[-1:], axis=0, inplace=True)

# %% [markdown]
# Кстати, важное замечание: фиксации здесь длиннее, чем в случае первой буквы S, так что диаметры сфер на графике домножены на коэффициент в 500 раз меньше, просто для удобства восприятия. Чтобы сравнивать графики между собой, нужно будет выровнять коэффициенты.

# %%
plot3 = figure(title="Matrix overlay", y_range=(1050,0), x_range=(0, 1680),
               plot_width=840,
               plot_height=525,
               x_axis_label='width, pixels', 
               y_axis_label='height, pixels')

x5=c2_fix_r['Location X']
y5=c2_fix_r['Location Y']
radii5 = c2_fix_r['Duration']*0.00002

x6=c2_fix_ur['Location X']
y6=c2_fix_ur['Location Y']
radii6 = c2_fix_ur['Duration']*0.00002

for item in coors:
    if item == sequence[6]:
        plot3.quad(top=item[1], bottom=item[3], left=item[0], right=item[2], color="orange", fill_alpha=0.3, line_color=None)
    else:
        plot3.quad(top=item[1], bottom=item[3], left=item[0], right=item[2], color="blue", fill_alpha=0.3, line_color=None)

plot3.circle(x6,y6, radius=radii6, fill_color="navy", fill_alpha=0.5, line_color=None, legend="irrelevant fixations")        
plot3.circle(x5,y5, radius=radii5, fill_color="orange", fill_alpha=0.6, line_color=None, legend="relevant fixations")

show(plot3)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="537783c7-16a9-4e40-8bd4-05c1585594da"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("537783c7-16a9-4e40-8bd4-05c1585594da").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("537783c7-16a9-4e40-8bd4-05c1585594da");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '537783c7-16a9-4e40-8bd4-05c1585594da' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b0410daf-37af-41d3-8dcb-f254d59071ef":{"roots":{"references":[{"attributes":{"bottom":{"value":380.3030303030303},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":941.5151515151515},"line_color":{"value":null},"right":{"value":1041.5151515151515},"top":{"value":480.3030303030303}},"id":"99922e0e-cb53-4d2e-947e-efc21cf4b6a5","type":"Quad"},{"attributes":{"bottom":{"value":475.0},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":335.4545454545455},"line_color":{"value":null},"right":{"value":435.4545454545455},"top":{"value":575.0}},"id":"2a3d4a06-6143-4195-a70f-65613e530699","type":"Quad"},{"attributes":{"callback":null},"id":"6b12b8c1-7a76-486a-88b6-63d26d720296","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"aa171dbd-fb65-41c9-bf7e-3e42104f8565","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ce391917-dd80-4ef3-92b6-01f86447bc9e","type":"PanTool"},{"id":"c2b9acec-a9fd-40ea-ba8a-347faf69fe0a","type":"WheelZoomTool"},{"id":"3b79b5e5-981c-4f82-92c2-cb4f54286fc1","type":"BoxZoomTool"},{"id":"658a2000-b5a5-492c-a167-0461361ca2a4","type":"SaveTool"},{"id":"8ddafbe7-f816-49cc-9f0c-cbbf87ddaf9d","type":"ResetTool"},{"id":"df53ad22-a54f-4560-82cd-4a598ab620ee","type":"HelpTool"}]},"id":"12a379f4-d04a-4358-ae78-bdb6f1fcc068","type":"Toolbar"},{"attributes":{"bottom":{"value":380.3030303030303},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"value":638.4848484848485},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":738.4848484848485},"top":{"value":480.3030303030303}},"id":"94e0576e-1e01-4039-92b9-2b2a5ecef3d1","type":"Quad"},{"attributes":{"label":{"value":"relevant fixations"},"renderers":[{"id":"ce2422f2-3c15-4073-b692-5edc938ca151","type":"GlyphRenderer"}]},"id":"014bbbee-f712-4401-86c3-07a18054f3de","type":"LegendItem"},{"attributes":{"callback":null},"id":"00708c6c-db03-4588-b73e-d250967c617e","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"1ed229d6-34ee-49e4-8542-16036d93d40c","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":285.6060606060606},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"value":486.969696969697},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":586.969696969697},"top":{"value":385.6060606060606}},"id":"588bd057-063f-4836-ba10-e3db3fa6ea4e","type":"Quad"},{"attributes":{"callback":null},"id":"a1d1a8d4-1547-45a2-97e4-d3022cd769b9","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":380.3030303030303},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"value":486.969696969697},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":586.969696969697},"top":{"value":480.3030303030303}},"id":"b208ffdf-e7cb-4f0a-9c14-80d04e65b6c7","type":"Quad"},{"attributes":{"bottom":{"value":475.0},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":941.5151515151515},"line_color":{"value":null},"right":{"value":1041.5151515151515},"top":{"value":575.0}},"id":"a258304e-c68c-43de-986e-bdd9d0c835d1","type":"Quad"},{"attributes":{"data_source":{"id":"0e93f823-6d9d-4315-a1b3-a82591cdd07d","type":"ColumnDataSource"},"glyph":{"id":"8964597d-213b-4fde-9e5e-18f8e06f40d0","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"94e0576e-1e01-4039-92b9-2b2a5ecef3d1","type":"Quad"},"selection_glyph":null},"id":"c255dafe-5629-421a-80b7-65a41df5d950","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":285.6060606060606},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":1093.030303030303},"line_color":{"value":null},"right":{"value":1193.030303030303},"top":{"value":385.6060606060606}},"id":"87d3262a-b909-4bde-bdd7-0a20b1819efd","type":"Quad"},{"attributes":{"bottom":{"value":190.90909090909093},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"le ...

# %% [markdown]
# И еще раз то же самое, для пробела в середине фразы. Релевантные фиксации:

# %%
space_fix=find_fixations(fixations, time=(markers.loc[742, 'Start'], markers.loc[847, 'Start']))
space_fix_r=find_fixations(fixations, area=sequence[7])
c2_fix_r
# Out:
#     index         Start          End  Duration  Location X  Location Y
# 0     136  1.139760e+10  11397675971   76245.0      941.63      264.73
# 1     149  1.140477e+10  11404826726   52126.0      961.99      272.63
# 2     168  1.141996e+10  11420174633  212059.0      954.77      271.05
# 3     296  1.147216e+10  11472229670   68006.0      984.12      251.09
# 4     298  1.147346e+10  11473900326  442085.0      953.39      270.00
# 5     301  1.147544e+10  11475679106  242090.0      946.97      225.00
# 6     302  1.147588e+10  11475933218   52001.0      947.11      220.30
# 7     305  1.147681e+10  11476911647  100097.0      951.89      283.26
# 54       64.86

# %%
plot4 = figure(title="Matrix overlay", y_range=(1050,0), x_range=(0, 1680),
               plot_width=840,
               plot_height=525,
               x_axis_label='width, pixels', 
               y_axis_label='height, pixels')

x7=space_fix_r['Location X']
y7=space_fix_r['Location Y']
radii7 = space_fix_r['Duration']*0.00002

x8=space_fix_ur['Location X']
y8=space_fix_ur['Location Y']
radii8 = space_fix_ur['Duration']*0.00002

for item in coors:
    if item == sequence[7]:
        plot4.quad(top=item[1], bottom=item[3], left=item[0], right=item[2], color="#32CD32", fill_alpha=0.3, line_color=None)
    else:
        plot4.quad(top=item[1], bottom=item[3], left=item[0], right=item[2], color="blue", fill_alpha=0.3, line_color=None)

plot4.circle(x8,y8, radius=radii8, fill_color="navy", fill_alpha=0.5, line_color=None, legend="irrelevant fixations")        
plot4.circle(x7,y7, radius=radii7, fill_color="#008000", fill_alpha=0.6, line_color=None, legend="relevant fixations")

show(plot4)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1411f1d3-401f-4ab2-8111-e741c57110e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1411f1d3-401f-4ab2-8111-e741c57110e6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1411f1d3-401f-4ab2-8111-e741c57110e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1411f1d3-401f-4ab2-8111-e741c57110e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7faa9164-918f-499c-afe5-945fbded549f":{"roots":{"references":[{"attributes":{"data_source":{"id":"b72b840f-2d6e-4781-abd5-65c8d117fb0c","type":"ColumnDataSource"},"glyph":{"id":"eb608419-a6d8-4a93-91a2-2433d39fd601","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"0ecbf980-db2f-4e04-ab83-46fdbb2d0eea","type":"Quad"},"selection_glyph":null},"id":"07b3421c-0532-471d-94a6-822205b61271","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":475.0},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":790.0},"line_color":{"value":null},"right":{"value":890.0},"top":{"value":575.0}},"id":"709e1f93-09a0-4795-b55b-d6de83f99393","type":"Quad"},{"attributes":{"bottom":{"value":664.3939393939394},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":1093.030303030303},"line_color":{"value":null},"right":{"value":1193.030303030303},"top":{"value":764.3939393939394}},"id":"5546ac4a-64ea-4347-919e-a8f7e5214c2e","type":"Quad"},{"attributes":{"bottom":{"value":475.0},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":1093.030303030303},"line_color":{"value":null},"right":{"value":1193.030303030303},"top":{"value":575.0}},"id":"2dfaed40-1939-4f4d-a616-9c10a3f6222f","type":"Quad"},{"attributes":{"callback":null},"id":"e08a234d-52f6-4833-86c2-73537e4313a2","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":475.0},"fill_alpha":{"value":0.3},"fill_color":{"value":"blue"},"left":{"value":486.969696969697},"line_color":{"value":null},"right":{"value":586.969696969697},"top":{"value":575.0}},"id":"a2fdcbc5-0e13-4516-a4af-53957201b004","type":"Quad"},{"attributes":{"items":[{"id":"3cb07b94-cf0b-40a6-97e8-4263afa2fd9b","type":"LegendItem"},{"id":"855e7288-16ca-46ce-8eff-6a440d0db365","type":"Legend